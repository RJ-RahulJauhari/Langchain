# %% [markdown]
# # Hugging Face Chat Models

# %%
import os

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from langchain_openai import ChatOpenAI

# Use your HF token as the "OpenAI" key since the endpoint is OpenAI-compatible
os.environ["OPENAI_API_KEY"] = os.environ["HUGGINGFACEHUB_ACCESS_TOKEN"]

llm = ChatOpenAI(
    model="deepseek-ai/DeepSeek-V3.2-Exp",
    base_url="https://router.huggingface.co/v1", 
    temperature=0.2,
)

resp = llm.invoke("Give me code for making full stack web app using MERN Stack")
print(resp)
# Out:
# content='I\'ll provide you with a complete MERN stack web application structure with code examples. Let\'s create a simple Task Manager application.\n\n## Project Structure\n```\nmern-task-app/\n├── backend/\n│   ├── models/\n│   ├── routes/\n│   ├── middleware/\n│   ├── config/\n│   └── server.js\n├── frontend/\n│   ├── public/\n│   ├── src/\n│   │   ├── components/\n│   │   ├── pages/\n│   │   ├── services/\n│   │   └── App.js\n│   └── package.json\n└── package.json\n```\n\n## Backend (Node.js + Express + MongoDB)\n\n### 1. Backend Package.json\n```json\n{\n  "name": "mern-task-app-backend",\n  "version": "1.0.0",\n  "description": "Backend for MERN Task App",\n  "main": "server.js",\n  "scripts": {\n    "start": "node server.js",\n    "dev": "nodemon server.js"\n  },\n  "dependencies": {\n    "express": "^4.18.2",\n    "mongoose": "^7.5.0",\n    "cors": "^2.8.5",\n    "dotenv": "^16.3.1",\n    "bcryptjs": "^2.4.3",\n    "jsonwebtoken": "^9.0.2"\n  },\n  "devDependencies": {\n    "
# ...

# %%
print(resp.content)
# Out:
# I'll provide you with a complete MERN stack web application structure with code examples. Let's create a simple Task Manager application.
#
# ## Project Structure
# ```
# mern-task-app/
# ├── backend/
# │   ├── models/
# │   ├── routes/
# │   ├── middleware/
# │   ├── config/
# │   └── server.js
# ├── frontend/
# │   ├── public/
# │   ├── src/
# │   │   ├── components/
# │   │   ├── pages/
# │   │   ├── services/
# │   │   └── App.js
# │   └── package.json
# └── package.json
# ```
#
# ## Backend (Node.js + Express + MongoDB)
#
# ### 1. Backend Package.json
# ```json
# {
#   "name": "mern-task-app-backend",
#   "version": "1.0.0",
#   "description": "Backend for MERN Task App",
#   "main": "server.js",
#   "scripts": {
#     "start": "node server.js",
#     "dev": "nodemon server.js"
#   },
#   "dependencies": {
#     "express": "^4.18.2",
#     "mongoose": "^7.5.0",
#     "cors": "^2.8.5",
#     "dotenv": "^16.3.1",
#     "bcryptjs": "^2.4.3",
#     "jsonwebtoken": "^9.0.2"
#   },
# ...

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="novita",
    api_key=os.environ["HUGGINGFACEHUB_ACCESS_TOKEN"],
)

completion = client.chat.completions.create(
    model="zai-org/GLM-4.6",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionOutputMessage(role='assistant', content='The capital of France is **Paris**.', reasoning=None, tool_call_id=None, tool_calls=None)

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.environ["HUGGINGFACEHUB_ACCESS_TOKEN"],
)

completion = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The capital of France is **Paris**.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='The user asks a straightforward factual question. Answer: Paris.')
