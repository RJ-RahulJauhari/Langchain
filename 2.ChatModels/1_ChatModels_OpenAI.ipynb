# %% [markdown]
# # Chat Models

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
chat_model = ChatOpenAI(model="gpt-4o", temperature=1.5, max_completion_tokens=200)

# %%
response = chat_model.invoke("What is the best way to learn Langchain?")
response
# Out:
# AIMessage(content="LangChain is an emerging framework designed for building scalable applications leveraging language models. Here's a structured approach to learning LangChain:\n\n1. **Understand the Basics**:\n   - **Familiarize with LLMs**: Understand the principles behind Large Language Models (LLMs) like GPT, ChatGPT, and others which LangChain utilizes extensively.\n   - **Get to Know the Ecosystem**: Understand where LangChain fits within the AI landscape. It’s largely geared towards facilitating LLM application building which may integrate with APIs or worklets.\n\n2. **Official Documentation**:\n   - Go through the official LangChain documentation. It’s usually a well-maintained and reliable resource for understanding functions, modules, and workflows.\n\n3. **Tutorials and Guides**:\n   - Start with beginner-friendly tutorials. Blogs and unofficial guides can provide practical insights.\n   - YouTube offers many video walkthroughs where content creators cover steps and tips that can be helpful.\n\n4. **Hands-on Projects**:\n", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 17, 'total_tokens': 217, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CKrz1kXjsaLl8Fhcy5i2Pmsh8TrPP', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='run--85c35d84-cd7b-4df4-9f3a-267cda81a2d1-0', usage_metadata={'input_tokens': 17, 'output_tokens': 200, 'total_tokens': 217, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
response.content
# Out:
# "LangChain is an emerging framework designed for building scalable applications leveraging language models. Here's a structured approach to learning LangChain:\n\n1. **Understand the Basics**:\n   - **Familiarize with LLMs**: Understand the principles behind Large Language Models (LLMs) like GPT, ChatGPT, and others which LangChain utilizes extensively.\n   - **Get to Know the Ecosystem**: Understand where LangChain fits within the AI landscape. It’s largely geared towards facilitating LLM application building which may integrate with APIs or worklets.\n\n2. **Official Documentation**:\n   - Go through the official LangChain documentation. It’s usually a well-maintained and reliable resource for understanding functions, modules, and workflows.\n\n3. **Tutorials and Guides**:\n   - Start with beginner-friendly tutorials. Blogs and unofficial guides can provide practical insights.\n   - YouTube offers many video walkthroughs where content creators cover steps and tips that can be helpful.\n\n4. **Hands-on Projects**:\n"
