# %% [markdown]
# # Embedding Model OpenAI

# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
embedding_model = OpenAIEmbeddings(model="text-embedding-3-large", dimensions=32)

# %%
embedding = embedding_model.embed_query("Hello world")

# %%
print(embedding)
# Out:
# [-0.06418027728796005, -0.0746091827750206, 0.04524441808462143, 0.23176737129688263, 0.05976926535367966, -0.047008827328681946, -0.030420254915952682, 0.5600729584693909, 0.20026011765003204, 0.2117287665605545, 0.014753272756934166, -0.08500657975673676, -0.14720189571380615, -0.14027030766010284, -0.03648540377616882, 0.2691980004310608, -0.09212721884250641, -0.019833818078041077, -0.05324726179242134, -0.13245651125907898, 0.16257743537425995, 0.027600355446338654, -0.12779343128204346, 0.4020325839519501, 0.02153521031141281, 0.17543239891529083, -0.10712467133998871, 0.043574534356594086, -0.2636527121067047, -0.20378893613815308, 0.04480331763625145, 0.1206727921962738]

# %%
len(embedding)
# Out:
# 32

# %%
for i in embedding:
    print(i)
    print("\n")
# Out:
# -0.06418027728796005
#
#
# -0.0746091827750206
#
#
# 0.04524441808462143
#
#
# 0.23176737129688263
#
#
# 0.05976926535367966
#
#
# -0.047008827328681946
#
#
# -0.030420254915952682
#
#
# 0.5600729584693909
#
#
# 0.20026011765003204
#
#
# 0.2117287665605545
#
#
# 0.014753272756934166
#
#
# -0.08500657975673676
#
#
# -0.14720189571380615
#
#
# -0.14027030766010284
#
#
# -0.03648540377616882
#
#
# 0.2691980004310608
#
#
# -0.09212721884250641
#
#
# -0.019833818078041077
#
#
# -0.05324726179242134
#
#
# -0.13245651125907898
#
#
# 0.16257743537425995
#
#
# 0.027600355446338654
#
#
# -0.12779343128204346
#
#
# 0.4020325839519501
#
#
# 0.02153521031141281
#
#
# 0.17543239891529083
#
#
# -0.10712467133998871
#
#
# 0.043574534356594086
#
#
# -0.2636527121067047
#
#
# -0.20378893613815308
#
#
# 0.04480331763625145
#
#
# 0.1206727921962738

# %%
#Embfrom
